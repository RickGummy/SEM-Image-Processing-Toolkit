# %%
# Set up libraries
import cv2
import numpy as np
import matplotlib.pyplot as plt
from scipy.spatial import distance
from scipy.spatial import KDTree

# %%
# Circularity function
def circularity(contour):
  area = cv2.contourArea(contour)
  perimeter = cv2.arcLength(contour, True)
  if(perimeter == 0):
    return 0
  return (4 * np.pi * area) / (perimeter ** 2)

# %%
# Overview
# Loads Image, Convert to grayscale, apply binary thresholding
# Find contours, calculate perimeter area circularity
# Filter based on thresholds
def process_image(image_path):
    # Load image
    image = cv2.imread(image_path, cv2.IMREAD_COLOR)
    assert image is not None, "Not found, check with os.path.exists() with os module"

    # Convert image from BGR to grayscale
    gray_image = cv2.cvtColor(np.array(image), cv2.COLOR_BGR2GRAY)

    # Enhance contrast using CLAHE
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    enhanced_image = clahe.apply(gray_image)

    # Apply Gaussian Blur to smooth the image
    blurred_image = cv2.GaussianBlur(enhanced_image, (5, 5), 0)

    # Apply binary thresholding for edge detection,
    _, threshold_image = cv2.threshold(blurred_image, 125, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)
    # 128 can be changed to make it less or more sensitive
    # Makes edges white on a black background

    # Find contours
    contours, _ = cv2.findContours(threshold_image, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Calculate perimeter, area, and circularity for each contour
    contour_data = []
    for contour in contours:
        perimeter = cv2.arcLength(contour, True)
        area = cv2.contourArea(contour)
        circ = circularity(contour)
        contour_data.append((contour, perimeter, area, circ))

    # Set thresholds for contours
    max_area_threshold = 30000
    area_threshold = 1000
    min_area_threshold = 100  # Minimum area to filter out tiny circles
    min_circularity_threshold = 0.5
    max_circularity_threshold = 1.5

    # Filter contours based on circularity and area
    filtered_contours = [data for data in contour_data if
                         ((min_area_threshold < data[2] < max_area_threshold)  and
                          (min_circularity_threshold <= data[3] <= max_circularity_threshold)) or
                          (min_area_threshold < data[2] < max_area_threshold)]

    # Draw filtered contours on the original image
    final_contour_image = np.array(image)
    for i, data in enumerate(filtered_contours):
        cv2.drawContours(final_contour_image, [data[0]], -1, (255, 0, 255), 1)  # Filtered contours in purple

        # Calculate the centroid
        M = cv2.moments(data[0])
        if M['m00'] != 0:
            cx = int(M['m10'] / M['m00'])
            cy = int(M['m01'] / M['m00'])
            # Annotate the contour with its index
            cv2.putText(final_contour_image, f"{i}", (cx, cy), cv2.FONT_HERSHEY_SIMPLEX, 0.8, (0, 0, 255), 2)
            print(f"Contour {i}: Centroid at ({cx}, {cy})")
        else:
            print(f"Contour {i}: Centroid not found (area too small).")

    # Display the image with filtered contours and axes
    plt.figure(figsize=(8, 6))
    plt.imshow(cv2.cvtColor(final_contour_image, cv2.COLOR_BGR2RGB))
    plt.xlabel('X-axis')
    plt.ylabel('Y-axis')
    plt.title('Filtered Contours with Indices and Centroids')
    plt.show()

    return image, filtered_contours, final_contour_image

# %%
# Use to manually exclusion contours, cause I don't know how to make an interactive environment
image_path = ('/Users/rickgummy/sem-image-processing-toolkit/data/raw/C1-3_A_m06.tif')
image, contours, final_contour_image = process_image(image_path)
# Out:
# Contour 0: Centroid at (53, 779)
# Contour 1: Centroid at (205, 774)
# Contour 2: Centroid at (289, 761)
# Contour 3: Centroid at (210, 746)
# Contour 4: Centroid at (723, 746)
# Contour 5: Centroid at (866, 742)
# Contour 6: Centroid at (162, 736)
# Contour 7: Centroid at (151, 698)
# Contour 8: Centroid at (248, 724)
# Contour 9: Centroid at (514, 718)
# Contour 10: Centroid at (184, 689)
# Contour 11: Centroid at (644, 710)
# Contour 12: Centroid at (372, 711)
# Contour 13: Centroid at (786, 706)
# Contour 14: Centroid at (59, 709)
# Contour 15: Centroid at (767, 653)
# Contour 16: Centroid at (198, 663)
# Contour 17: Centroid at (680, 636)
# Contour 18: Centroid at (947, 683)
# Contour 19: Centroid at (1113, 675)
# Contour 20: Centroid at (590, 636)
# Contour 21: Centroid at (474, 632)
# Contour 22: Centroid at (258, 632)
# Contour 23: Centroid at (1243, 658)
# Contour 24: Centroid at (702, 597)
# Contour 25: Centroid at (359, 611)
# Contour 26: Centroid at (12, 612)
# Contour 27: Centroid at (124, 602)
# Contour 28: Centroid at (1028, 570)
# Contour 29: Centroid at (847, 577)
# Contour 30: Centroid at (1189, 561)
# Contour 31: Centroid at (714, 537)
# Contour 32: Centroid at (264, 544)
# Contour 33: Centroid at (569, 553)
# Contour 34: Centroid at (419, 541)
# Contour 35: Centroid at (573, 504)
# Contour 36: Centroid at (1039, 501)
# Contour 37: Centroid at (975, 506)
# Contour 38: Centroid at (29, 517)
# Contour 39: Centroid at (1104, 499)
# Contour 40: Centroid at (222, 482)
# Contour 41: Centroid at (143, 498)
# Contour 42: Centroid at (679, 470)
# Contour 43: Centroid at (796, 468)
# Contour 44: Centroid at (315, 462)
# Contour 45: Centroid at (1056, 439)
# Contour 46: Centroid at (589, 433)
# Contour 47: Centroid at (464, 446)
# Contour 48: Centroid at (936, 443)
# Contour 49: Centroid at (1221, 436)
# Contour 50: Centroid at (201, 404)
# Contour 51: Centroid at (53, 407)
# Contour 52: Centroid at (703, 385)
# Contour 53: Centroid at (1013, 365)
# Contour 54: Centroid at (759, 335)
# Contour 55: Centroid at (356, 364)
# Contour 56: Centroid at (848, 361)
# Contour 57: Centroid at (172, 324)
# Contour 58: Centroid at (961, 334)
# Contour 59: Centroid at (1131, 351)
# Contour 60: Centroid at (1252, 322)
# Contour 61: Centroid at (1203, 300)
# Contour 62: Centroid at (559, 327)
# Contour 63: Centroid at (236, 304)
# Contour 64: Centroid at (1034, 283)
# Contour 65: Centroid at (422, 293)
# Contour 66: Centroid at (241, 247)
# Contour 67: Centroid at (187, 231)
# Contour 68: Centroid at (904, 253)
# Contour 69: Centroid at (732, 264)
# Contour 70: Centroid at (1160, 242)
# Contour 71: Centroid at (81, 263)
# Contour 72: Centroid at (1266, 216)
# Contour 73: Centroid at (314, 238)
# Contour 74: Centroid at (1039, 169)
# Contour 75: Centroid at (702, 143)
# Contour 76: Centroid at (680, 87)
# Contour 77: Centroid at (13, 133)
# Contour 78: Centroid at (1225, 108)
# Contour 79: Centroid at (732, 22)
# Contour 80: Centroid at (1248, 6)
# Contour 81: Centroid at (1064, 37)
# Contour 82: Centroid at (660, 28)
# Contour 83: Centroid at (407, 14)

# %%
# Overview
# Loads Image, Convert to grayscale, apply binary thresholding
# Find contours, calculate perimeter area circularity
# Filter based on thresholds
def process_image_with_exclusion(image_path, exclude_coords):
    # Load image
    image = cv2.imread(image_path, cv2.IMREAD_COLOR)
    assert image is not None, "Not found, check with os.path.exists() with os module"

    # Convert image from BGR to grayscale
    gray_image = cv2.cvtColor(np.array(image), cv2.COLOR_BGR2GRAY)

    # Enhance contrast using CLAHE
    clahe = cv2.createCLAHE(clipLimit=2.0, tileGridSize=(8, 8))
    enhanced_image = clahe.apply(gray_image)

    # Apply Gaussian Blur to smooth the image
    blurred_image = cv2.GaussianBlur(enhanced_image, (5, 5), 0)

    # Apply binary thresholding for edge detection
    _, threshold_image = cv2.threshold(blurred_image, 125, 255, cv2.THRESH_BINARY_INV + cv2.THRESH_OTSU)

    # Find contours
    contours, _ = cv2.findContours(threshold_image, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

    # Calculate perimeter, area, and circularity for each contour
    contour_data = []
    for contour in contours:
        perimeter = cv2.arcLength(contour, True)
        area = cv2.contourArea(contour)
        circ = circularity(contour)
        contour_data.append((contour, perimeter, area, circ))

    # Set thresholds for contours
    max_area_threshold = 20000
    area_threshold = 1000
    min_area_threshold = 100  # Minimum area to filter out tiny circles
    min_circularity_threshold = 0.5
    max_circularity_threshold = 1.5

    # Filter contours based on circularity and area
    filtered_contours = []
    for data in contour_data:
        if ((min_area_threshold < data[2] < max_area_threshold) and (min_circularity_threshold <= data[3] <= max_circularity_threshold)) or (min_area_threshold < data[2] < max_area_threshold):
            # Calculate the centroid
            M = cv2.moments(data[0])
            if M['m00'] != 0:
                cx = int(M['m10'] / M['m00'])
                cy = int(M['m01'] / M['m00'])
                if (cx, cy) not in exclude_coords:
                    filtered_contours.append(data)
            else:
                filtered_contours.append(data)

    # Draw filtered contours on the original image
    final_contour_image = np.array(image)
    cv2.drawContours(final_contour_image, [data[0] for data in filtered_contours], -1, (255, 0, 255), 2)  # Filtered contours in purple

    # Display the image with filtered contours
    plt.figure(figsize=(8, 6))
    plt.imshow(cv2.cvtColor(final_contour_image, cv2.COLOR_BGR2RGB))
    plt.axis('off')
    plt.title('Filtered Contours based on exclusion list')
    plt.show()

    return image, filtered_contours, area_threshold, final_contour_image

# %%
def bounding_box_overlap(box1, box2, margin = 35):
  return not(box1[2] + margin < box2[0] or # box1 right < box2 left
             box1[0] - margin > box2[2] or # box1 left > box2 right
             box1[3] + margin < box2[1] or # box1 bottom < box2 top
             box1[1] - margin > box2[3])   # box1 top > box2 bottom

# %%
# Calculate centroids of contours
# Using KDTree to find neighboring contours
# Find closest points between neighboring contours
# Draw lines showing closest distances
def cwDistance(image, contours, area_threshold, max_neighbors = 8, max_distance = 100, min_distance = 5):
  distances = []
  line_coords = []
  contour_pairs = set()

  # Calculate the centroids and bounding boxes for small contours only
  centroids = []
  bounding_boxes = []
  for data in contours:
    contour = data[0]
    M = cv2.moments(contour)
    if M['m00'] != 0:
      cx = int(M['m10'] / M['m00'])
      cy = int(M['m01'] / M['m00'])
      centroids.append((cx, cy))
    else:
      centroids.append((0, 0))
    x, y, w, h = cv2.boundingRect(contour)
    bounding_boxes.append((x, y, x + w, y + h))

  print(f"Number of centroids: {len(centroids)}")

  # Create a KDTree for the centroids
  tree = KDTree(centroids)

  for i, data1 in enumerate(contours):
    contour1 = data1[0]
    points1 = contour1[:, 0, :] # extract points from contour1
    tree1 = KDTree(points1)

    # Find indices of the closest neighboring centroids
    distances_to_neighbors, neighbor_indices = tree.query(centroids[i], k=max_neighbors + 1)
    neighbor_indicies = neighbor_indices[1:] # Excludes itself

    for j in neighbor_indices:
      if i == j in contour_pairs or (j, i) in contour_pairs:
        continue
      if bounding_box_overlap(bounding_boxes[i], bounding_boxes[j]):
        contour2 = contours[j][0]
        points2 = contour2[:, 0, :] # extract points from contour2
        tree2 = KDTree(points2)

        # Find the closest point between contour1 and contour2
        min_dist = float('inf')
        closest_points = None
        for point in points1:
          dist, idx = tree2.query(point)
          if dist < min_dist:
            min_dist = dist
            closest_points = (tuple(point), tuple(points2[idx]))

        for point in points2:
          dist, idx = tree1.query(point)
          if dist < min_dist:
            min_dist = dist
            closest_points = (tuple(points1[idx]), tuple(point))

        print(f"Min distance found between contours: {min_dist}")

        # Stores and draws the closest points
        if closest_points and min_distance <= min_dist <= max_distance:
          distances.append(min_dist)
          line_coords.append(closest_points)
          cv2.line(image,closest_points[0], closest_points[1], (0, 0, 255), 2)
          contour_pairs.add((i, j))
        else:
           print(f"No valid distance found for contours {i} and {j} (min_distance={min_distance}, max_distance={max_distance})")

  # Draw contours
  cv2.drawContours(image, [data[0] for data in contours], -1, (0, 255, 0), 1) # Big contours in blue

  # Save distances as file
  with open('distances.txt', 'w') as f:
    for dist in distances:
      f.write(f'{dist}\n')

  # Display image with lines
  plt.figure(figsize = (14, 12))
  plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
  plt.axis('off')
  plt.title('Contours with Cell Wall Distances max_neighbors = 10, max_distance = 200, min_distance = 5')
  plt.show()

  return distances, line_coords

# %%
def remove_outliers(data):
  q1 = np.percentile(data, 25)
  q3 = np.percentile(data, 75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5 * iqr
  upper_bound = q3 + 1.5 * iqr
  return [x for x in data if lower_bound <= x <= upper_bound]

# %%
def calculate_and_plot_statistics(image, contours):
  # Remove outliers from distances and calculate the average
  median_thickness = np.median(distances)
  print(f'Median cell wall thickness: {median_thickness:.2f}')
  filtered_distances = remove_outliers(distances)
  average_thickness = np.mean(filtered_distances)
  print(f'Average cell wall thickness(without outliers): {average_thickness: .2f} pixels')

  # Calculate areas of big and small contours
  areas = [data[2] for data in contours]

  filtered_areas = remove_outliers(areas)
  average_area = np.mean(filtered_areas)
  print(f'Average cell area(without outliers): {average_area: .2f} pixels^2')

  # Plot box plots for distances
  plt.figure(figsize = (14, 7))

  plt.subplot(1, 2, 1)
  plt.boxplot(distances, vert = True, patch_artist = True)
  plt.title('Cell Wall thickness(include outliers)')
  plt.xlabel('Thickness (pixels)')

  plt.subplot(1, 2, 2)
  plt.boxplot(areas, vert = True, patch_artist=True)
  plt.title('Contour Areas (including outliers)')
  plt.xlabel('Area (pixels^2)')

  plt.tight_layout()
  plt.show()

# %%
image_path = ('/Users/rickgummy/sem-image-processing-toolkit/data/raw/C1-3_A_m06.tif')
exclude_coords = []
image, contours, area_threshold, final_contour_image = process_image_with_exclusion(image_path, exclude_coords)
distances, line_coords = cwDistance(image, contours,area_threshold, max_neighbors = 8, max_distance = 100, min_distance = 5)
calculate_and_plot_statistics(image, contours)
# Out:
# Number of centroids: 84
# Min distance found between contours: 0.0
# No valid distance found for contours 0 and 0 (min_distance=5, max_distance=100)
# Min distance found between contours: 16.76305461424021
# Min distance found between contours: 0.0
# No valid distance found for contours 1 and 1 (min_distance=5, max_distance=100)
# Min distance found between contours: 19.1049731745428
# Min distance found between contours: 20.09975124224178
# Min distance found between contours: 19.924858845171276
# Min distance found between contours: 0.0
# No valid distance found for contours 2 and 2 (min_distance=5, max_distance=100)
# Min distance found between contours: 12.727922061357855
# Min distance found between contours: 13.45362404707371
# Min distance found between contours: 0.0
# No valid distance found for contours 3 and 3 (min_distance=5, max_distance=100)
# Min distance found between contours: 5.0990195135927845
# Min distance found between contours: 4.0
# No valid distance found for contours 3 and 6 (min_distance=5, max_distance=100)
# Min distance found between contours: 0.0
# No valid distance found for contours 4 and 4 (min_distance=5, max_distance=100)
# Min distance found between contours: 9.848857801796104
# Min distance found between contours: 17.46424919657298
# Min distance found between contours: 0.0
# No valid distance found for contours 5 and 5 (min_distance=5, max_distance=100)
# Min distance found between contours: 16.278820596099706
# Min distance found between contours: 14.866068747318506
# Min distance found between contours: 0.0
# No valid distance found for contours 6 and 6 (min_distance=5, max_distance=100)
# Min distance found between contours: 6.0
# Min distance found between contours: 4.0
# No valid distance found for contours 6 and 3 (min_distance=5, max_distance=100)
# Min distance found between contours: 28.653097563788805
# Min distance found between contours: 29.614185789921695
# Min distance found between contours: 19.1049731745428
# Min distance found between contours: 0.0
# No valid distance found for contours 7 and 7 (min_distance=5, max_distance=100)
# Min distance found between contours: 16.55294535724685
# Min distance found between contours: 34.132096331752024
# Min distance found between contours: 19.026297590440446
# Min distance found between contours: 35.05709628591621
# Min distance found between contours: 0.0
# No valid distance found for contours 8 and 8 (min_distance=5, max_distance=100)
# Min distance found between contours: 31.0
# Min distance found between contours: 31.38470965295043
# Min distance found between contours: 25.059928172283335
# Min distance found between contours: 0.0
# No valid distance found for contours 9 and 9 (min_distance=5, max_distance=100)
# Min distance found between contours: 25.0
# Min distance found between contours: 26.832815729997478
# Min distance found between contours: 18.24828759089466
# Min distance found between contours: 15.231546211727817
# Min distance found between contours: 0.0
# No valid distance found for contours 10 and 10 (min_distance=5, max_distance=100)
# Min distance found between contours: 15.0
# Min distance found between contours: 53.53503525729669
# Min distance found between contours: 29.154759474226502
# Min distance found between contours: 0.0
# No valid distance found for contours 11 and 11 (min_distance=5, max_distance=100)
# Min distance found between contours: 25.0
# Min distance found between contours: 24.186773244895647
# Min distance found between contours: 52.69724850502159
# Min distance found between contours: 18.24828759089466
# Min distance found between contours: 0.0
# No valid distance found for contours 12 and 12 (min_distance=5, max_distance=100)
# Min distance found between contours: 38.0
# Min distance found between contours: 20.12461179749811
# Min distance found between contours: 24.839484696748443
# Min distance found between contours: 30.01666203960727
# Min distance found between contours: 0.0
# No valid distance found for contours 13 and 13 (min_distance=5, max_distance=100)
# Min distance found between contours: 11.40175425099138
# Min distance found between contours: 42.20189569201838
# Min distance found between contours: 39.45883931389772
# Min distance found between contours: 18.110770276274835
# Min distance found between contours: 0.0
# No valid distance found for contours 14 and 14 (min_distance=5, max_distance=100)
# Min distance found between contours: 27.294688127912362
# Min distance found between contours: 25.059928172283335
# Min distance found between contours: 0.0
# No valid distance found for contours 15 and 15 (min_distance=5, max_distance=100)
# Min distance found between contours: 42.5440947723653
# Min distance found between contours: 27.294688127912362
# Min distance found between contours: 0.0
# No valid distance found for contours 16 and 16 (min_distance=5, max_distance=100)
# Min distance found between contours: 15.132745950421556
# Min distance found between contours: 17.88854381999832
# Min distance found between contours: 0.0
# No valid distance found for contours 17 and 17 (min_distance=5, max_distance=100)
# Min distance found between contours: 20.248456731316587
# Min distance found between contours: 29.732137494637012
# Min distance found between contours: 0.0
# No valid distance found for contours 18 and 18 (min_distance=5, max_distance=100)
# Min distance found between contours: 32.57299494980466
# Min distance found between contours: 39.824615503479755
# Min distance found between contours: 20.024984394500787
# Min distance found between contours: 0.0
# No valid distance found for contours 19 and 19 (min_distance=5, max_distance=100)
# Min distance found between contours: 17.0
# Min distance found between contours: 34.40930106817051
# Min distance found between contours: 28.844410203711913
# Min distance found between contours: 0.0
# No valid distance found for contours 20 and 20 (min_distance=5, max_distance=100)
# Min distance found between contours: 25.079872407968907
# Min distance found between contours: 24.166091947189145
# Min distance found between contours: 29.966648127543394
# Min distance found between contours: 0.0
# No valid distance found for contours 21 and 21 (min_distance=5, max_distance=100)
# Min distance found between contours: 32.69556544854363
# Min distance found between contours: 24.186773244895647
# Min distance found between contours: 30.083217912982647
# Min distance found between contours: 0.0
# No valid distance found for contours 22 and 22 (min_distance=5, max_distance=100)
# Min distance found between contours: 25.179356624028344
# Min distance found between contours: 23.259406699226016
# Min distance found between contours: 0.0
# No valid distance found for contours 23 and 23 (min_distance=5, max_distance=100)
# Min distance found between contours: 29.5296461204668
# Min distance found between contours: 0.0
# No valid distance found for contours 24 and 24 (min_distance=5, max_distance=100)
# Min distance found between contours: 27.018512172212592
# Min distance found between contours: 32.526911934581186
# Min distance found between contours: 0.0
# No valid distance found for contours 25 and 25 (min_distance=5, max_distance=100)
# Min distance found between contours: 27.85677655436824
# Min distance found between contours: 29.410882339705484
# Min distance found between contours: 0.0
# No valid distance found for contours 26 and 26 (min_distance=5, max_distance=100)
# Min distance found between contours: 32.55764119219941
# Min distance found between contours: 26.68332812825267
# Min distance found between contours: 0.0
# No valid distance found for contours 27 and 27 (min_distance=5, max_distance=100)
# Min distance found between contours: 34.058772731852805
# Min distance found between contours: 38.47076812334269
# Min distance found between contours: 26.570660511172846
# Min distance found between contours: 0.0
# No valid distance found for contours 28 and 28 (min_distance=5, max_distance=100)
# Min distance found between contours: 22.20360331117452
# Min distance found between contours: 25.079872407968907
# Min distance found between contours: 29.5296461204668
# Min distance found between contours: 29.017236257093817
# Min distance found between contours: 0.0
# No valid distance found for contours 29 and 29 (min_distance=5, max_distance=100)
# Min distance found between contours: 37.0
# Min distance found between contours: 29.154759474226502
# Min distance found between contours: 35.35533905932738
# Min distance found between contours: 27.294688127912362
# Min distance found between contours: 0.0
# No valid distance found for contours 30 and 30 (min_distance=5, max_distance=100)
# Min distance found between contours: 30.805843601498726
# Min distance found between contours: 35.014282800023196
# Min distance found between contours: 0.0
# No valid distance found for contours 31 and 31 (min_distance=5, max_distance=100)
# Min distance found between contours: 27.51363298439521
# Min distance found between contours: 26.832815729997478
# Min distance found between contours: 26.570660511172846
# Min distance found between contours: 0.0
# No valid distance found for contours 32 and 32 (min_distance=5, max_distance=100)
# Min distance found between contours: 23.706539182259394
# Min distance found between contours: 32.7566787083184
# Min distance found between contours: 30.610455730027933
# Min distance found between contours: 33.60059523282288
# Min distance found between contours: 0.0
# No valid distance found for contours 33 and 33 (min_distance=5, max_distance=100)
# Min distance found between contours: 14.866068747318506
# Min distance found between contours: 37.57658845611187
# Min distance found between contours: 0.0
# No valid distance found for contours 34 and 34 (min_distance=5, max_distance=100)
# Min distance found between contours: 32.55764119219941
# Min distance found between contours: 28.178005607210743
# Min distance found between contours: 28.160255680657446
# Min distance found between contours: 42.01190307520001
# Min distance found between contours: 0.0
# No valid distance found for contours 35 and 35 (min_distance=5, max_distance=100)
# Min distance found between contours: 34.0147027033899
# Min distance found between contours: 44.598206241955516
# Min distance found between contours: 0.0
# No valid distance found for contours 36 and 36 (min_distance=5, max_distance=100)
# Min distance found between contours: 16.492422502470642
# Min distance found between contours: 22.360679774997898
# Min distance found between contours: 14.866068747318506
# Min distance found between contours: 0.0
# No valid distance found for contours 37 and 37 (min_distance=5, max_distance=100)
# Min distance found between contours: 23.853720883753127
# Min distance found between contours: 27.202941017470888
# Min distance found between contours: 0.0
# No valid distance found for contours 38 and 38 (min_distance=5, max_distance=100)
# Min distance found between contours: 28.460498941515414
# Min distance found between contours: 29.120439557122072
# Min distance found between contours: 0.0
# No valid distance found for contours 39 and 39 (min_distance=5, max_distance=100)
# Min distance found between contours: 26.832815729997478
# Min distance found between contours: 26.1725046566048
# Min distance found between contours: 0.0
# No valid distance found for contours 40 and 40 (min_distance=5, max_distance=100)
# Min distance found between contours: 18.973665961010276
# Min distance found between contours: 26.0
# Min distance found between contours: 21.93171219946131
# Min distance found between contours: 0.0
# No valid distance found for contours 41 and 41 (min_distance=5, max_distance=100)
# Min distance found between contours: 31.016124838541646
# Min distance found between contours: 32.55764119219941
# Min distance found between contours: 0.0
# No valid distance found for contours 42 and 42 (min_distance=5, max_distance=100)
# Min distance found between contours: 29.068883707497267
# Min distance found between contours: 28.844410203711913
# Min distance found between contours: 26.0
# Min distance found between contours: 0.0
# No valid distance found for contours 43 and 43 (min_distance=5, max_distance=100)
# Min distance found between contours: 32.2490309931942
# Min distance found between contours: 37.12142238654117
# Min distance found between contours: 29.0
# Min distance found between contours: 0.0
# No valid distance found for contours 44 and 44 (min_distance=5, max_distance=100)
# Min distance found between contours: 34.20526275297414
# Min distance found between contours: 29.206163733020468
# Min distance found between contours: 30.364452901377952
# Min distance found between contours: 0.0
# No valid distance found for contours 45 and 45 (min_distance=5, max_distance=100)
# Min distance found between contours: 30.463092423455635
# Min distance found between contours: 28.178005607210743
# Min distance found between contours: 23.08679276123039
# Min distance found between contours: 0.0
# No valid distance found for contours 46 and 46 (min_distance=5, max_distance=100)
# Min distance found between contours: 36.6742416417845
# Min distance found between contours: 28.319604517012593
# Min distance found between contours: 29.0
# Min distance found between contours: 0.0
# No valid distance found for contours 47 and 47 (min_distance=5, max_distance=100)
# Min distance found between contours: 38.897300677553446
# Min distance found between contours: 32.202484376209235
# Min distance found between contours: 37.64306044943742
# Min distance found between contours: 0.0
# No valid distance found for contours 48 and 48 (min_distance=5, max_distance=100)
# Min distance found between contours: 30.23243291566195
# Min distance found between contours: 35.805027579936315
# Min distance found between contours: 0.0
# No valid distance found for contours 49 and 49 (min_distance=5, max_distance=100)
# Min distance found between contours: 35.90264614203248
# Min distance found between contours: 33.015148038438355
# Min distance found between contours: 30.805843601498726
# Min distance found between contours: 0.0
# No valid distance found for contours 50 and 50 (min_distance=5, max_distance=100)
# Min distance found between contours: 34.23448553724738
# Min distance found between contours: 34.52535300326414
# Min distance found between contours: 30.805843601498726
# Min distance found between contours: 39.81205847478876
# Min distance found between contours: 0.0
# No valid distance found for contours 51 and 51 (min_distance=5, max_distance=100)
# Min distance found between contours: 34.92849839314596
# Min distance found between contours: 0.0
# No valid distance found for contours 52 and 52 (min_distance=5, max_distance=100)
# Min distance found between contours: 15.0
# Min distance found between contours: 33.24154027718932
# Min distance found between contours: 30.0
# Min distance found between contours: 32.202484376209235
# Min distance found between contours: 0.0
# No valid distance found for contours 53 and 53 (min_distance=5, max_distance=100)
# Min distance found between contours: 26.419689627245813
# Min distance found between contours: 33.13608305156178
# Min distance found between contours: 26.68332812825267
# Min distance found between contours: 0.0
# No valid distance found for contours 54 and 54 (min_distance=5, max_distance=100)
# Min distance found between contours: 20.591260281974
# Min distance found between contours: 22.090722034374522
# Min distance found between contours: 0.0
# No valid distance found for contours 55 and 55 (min_distance=5, max_distance=100)
# Min distance found between contours: 28.635642126552707
# Min distance found between contours: 36.22154055254967
# Min distance found between contours: 37.53664875824692
# Min distance found between contours: 0.0
# No valid distance found for contours 56 and 56 (min_distance=5, max_distance=100)
# Min distance found between contours: 26.019223662515376
# Min distance found between contours: 32.0624390837628
# Min distance found between contours: 36.89173349139343
# Min distance found between contours: 0.0
# No valid distance found for contours 57 and 57 (min_distance=5, max_distance=100)
# Min distance found between contours: 17.46424919657298
# Min distance found between contours: 21.213203435596427
# Min distance found between contours: 0.0
# No valid distance found for contours 58 and 58 (min_distance=5, max_distance=100)
# Min distance found between contours: 24.041630560342615
# Min distance found between contours: 30.463092423455635
# Min distance found between contours: 0.0
# No valid distance found for contours 59 and 59 (min_distance=5, max_distance=100)
# Min distance found between contours: 13.45362404707371
# Min distance found between contours: 35.35533905932738
# Min distance found between contours: 34.828149534535996
# Min distance found between contours: 29.068883707497267
# Min distance found between contours: 0.0
# No valid distance found for contours 60 and 60 (min_distance=5, max_distance=100)
# Min distance found between contours: 22.0
# Min distance found between contours: 50.15974481593781
# Min distance found between contours: 0.0
# No valid distance found for contours 61 and 61 (min_distance=5, max_distance=100)
# Min distance found between contours: 21.840329667841555
# Min distance found between contours: 0.0
# No valid distance found for contours 62 and 62 (min_distance=5, max_distance=100)
# Min distance found between contours: 27.80287754891569
# Min distance found between contours: 27.730849247724095
# Min distance found between contours: 0.0
# No valid distance found for contours 63 and 63 (min_distance=5, max_distance=100)
# Min distance found between contours: 20.248456731316587
# Min distance found between contours: 34.20526275297414
# Min distance found between contours: 21.93171219946131
# Min distance found between contours: 36.013886210738214
# Min distance found between contours: 0.0
# No valid distance found for contours 64 and 64 (min_distance=5, max_distance=100)
# Min distance found between contours: 33.015148038438355
# Min distance found between contours: 27.892651361962706
# Min distance found between contours: 32.01562118716424
# Min distance found between contours: 0.0
# No valid distance found for contours 65 and 65 (min_distance=5, max_distance=100)
# Min distance found between contours: 25.553864678361276
# Min distance found between contours: 0.0
# No valid distance found for contours 66 and 66 (min_distance=5, max_distance=100)
# Min distance found between contours: 15.0
# Min distance found between contours: 11.661903789690601
# Min distance found between contours: 0.0
# No valid distance found for contours 67 and 67 (min_distance=5, max_distance=100)
# Min distance found between contours: 25.238858928247925
# Min distance found between contours: 0.0
# No valid distance found for contours 68 and 68 (min_distance=5, max_distance=100)
# Min distance found between contours: 26.90724809414742
# Min distance found between contours: 29.120439557122072
# Min distance found between contours: 0.0
# No valid distance found for contours 69 and 69 (min_distance=5, max_distance=100)
# Min distance found between contours: 25.495097567963924
# Min distance found between contours: 0.0
# No valid distance found for contours 70 and 70 (min_distance=5, max_distance=100)
# Min distance found between contours: 27.892651361962706
# Min distance found between contours: 31.827660925679098
# Min distance found between contours: 39.66106403010388
# Min distance found between contours: 0.0
# No valid distance found for contours 71 and 71 (min_distance=5, max_distance=100)
# Min distance found between contours: 30.610455730027933
# Min distance found between contours: 49.040799340956916
# Min distance found between contours: 0.0
# No valid distance found for contours 72 and 72 (min_distance=5, max_distance=100)
# Min distance found between contours: 29.546573405388315
# Min distance found between contours: 0.0
# No valid distance found for contours 73 and 73 (min_distance=5, max_distance=100)
# Min distance found between contours: 0.0
# No valid distance found for contours 74 and 74 (min_distance=5, max_distance=100)
# Min distance found between contours: 26.076809620810597
# Min distance found between contours: 30.805843601498726
# Min distance found between contours: 0.0
# No valid distance found for contours 75 and 75 (min_distance=5, max_distance=100)
# Min distance found between contours: 10.295630140987
# Min distance found between contours: 3.605551275463989
# No valid distance found for contours 75 and 82 (min_distance=5, max_distance=100)
# Min distance found between contours: 0.0
# No valid distance found for contours 76 and 76 (min_distance=5, max_distance=100)
# Min distance found between contours: 17.46424919657298
# Min distance found between contours: 0.0
# No valid distance found for contours 77 and 77 (min_distance=5, max_distance=100)
# Min distance found between contours: 0.0
# No valid distance found for contours 78 and 78 (min_distance=5, max_distance=100)
# Min distance found between contours: 27.16615541441225
# Min distance found between contours: 27.65863337187866
# Min distance found between contours: 0.0
# No valid distance found for contours 79 and 79 (min_distance=5, max_distance=100)
# Min distance found between contours: 25.0
# Min distance found between contours: 0.0
# No valid distance found for contours 80 and 80 (min_distance=5, max_distance=100)
# Min distance found between contours: 21.02379604162864
# Min distance found between contours: 0.0
# No valid distance found for contours 81 and 81 (min_distance=5, max_distance=100)
# Min distance found between contours: 0.0
# No valid distance found for contours 82 and 82 (min_distance=5, max_distance=100)
# Min distance found between contours: 3.605551275463989
# No valid distance found for contours 82 and 75 (min_distance=5, max_distance=100)
# Min distance found between contours: 0.0
# No valid distance found for contours 83 and 83 (min_distance=5, max_distance=100)
# Median cell wall thickness: 28.18
# Average cell wall thickness(without outliers):  27.42 pixels
# Average cell area(without outliers):  4427.12 pixels^2
